# %%
from sklearn.datasets import fetch_openml
from sklearn.decomposition import PCA
import numpy as np
import matplotlib.pyplot as plt
import scipy.io as sio
# %matplotlib inline


# Dimension reduction and clustering libraries
# %pip install umap-learn
import umap
# %pip install hdbscan
import hdbscan
import sklearn.cluster as cluster
from sklearn.metrics import adjusted_rand_score, adjusted_mutual_info_score
from sklearn.preprocessing import LabelEncoder
# Out:
# Requirement already satisfied: umap-learn in /opt/anaconda3/lib/python3.12/site-packages (0.5.7)
# Requirement already satisfied: numpy>=1.17 in /opt/anaconda3/lib/python3.12/site-packages (from umap-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from umap-learn) (1.13.1)
# Requirement already satisfied: scikit-learn>=0.22 in /opt/anaconda3/lib/python3.12/site-packages (from umap-learn) (1.5.1)
# Requirement already satisfied: numba>=0.51.2 in /opt/anaconda3/lib/python3.12/site-packages (from umap-learn) (0.60.0)
# Requirement already satisfied: pynndescent>=0.5 in /opt/anaconda3/lib/python3.12/site-packages (from umap-learn) (0.5.13)
# Requirement already satisfied: tqdm in /opt/anaconda3/lib/python3.12/site-packages (from umap-learn) (4.66.5)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /opt/anaconda3/lib/python3.12/site-packages (from numba>=0.51.2->umap-learn) (0.43.0)
# Requirement already satisfied: joblib>=0.11 in /opt/anaconda3/lib/python3.12/site-packages (from pynndescent>=0.5->umap-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from scikit-learn>=0.22->umap-learn) (3.5.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: hdbscan in /opt/anaconda3/lib/python3.12/site-packages (0.8.40)
# Requirement already satisfied: numpy<3,>=1.20 in /opt/anaconda3/lib/python3.12/site-packages (from hdbscan) (1.26.4)
# Requirement already satisfied: scipy>=1.0 in /opt/anaconda3/lib/python3.12/site-packages (from hdbscan) (1.13.1)
# Requirement already satisfied: scikit-learn>=0.20 in /opt/anaconda3/lib/python3.12/site-packages (from hdbscan) (1.5.1)
# Requirement already satisfied: joblib>=1.0 in /opt/anaconda3/lib/python3.12/site-packages (from hdbscan) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from scikit-learn>=0.20->hdbscan) (3.5.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Load in the test data.

# %%
sub4test = np.load("/Users/jenniferarakaki/Documents/neuro120/8275363/sub-004_Resp_Test.npy")
print(sub4test.shape)
# Out:
# (61899, 4, 600)

# %% [markdown]
# Create a genre label vector to feed into the UMAP function.

# %%
# Load the .mat file (adjust the path if needed)
data = sio.loadmat('/Users/jenniferarakaki/Documents/neuro120/8275363/AcrossGenre_Order_Test.mat')
test_run_data = data['across_genre_rn_test']  # shape: (6 runs, 4 reps, 10 genres)

# Step 1: Extract numeric genre IDs
genre_labels = []
for run in range(6):  # 6 runs
    for track_pos in range(10):  # 10 tracks per run
        genre_id = int(test_run_data[run, 0, track_pos])
        genre_labels.append(genre_id)  # values: 1–10

# Step 2: Repeat each genre label 4 times (for 4 reps)
genre_labels_full = np.repeat(genre_labels, 4)  # shape: (240,)

# Step 3: Repeat for 5 subjects
genre_labels_full_all = np.tile(genre_labels_full, 5)  # shape: (1200,)

# Step 4: Convert to names using the corrected mapping
genre_names = [
    'country',    # index 1
    'reggae',     # index 2
    'rock',       # index 3
    'blues',      # index 4
    'classical',  # index 5
    'hiphop',     # index 6
    'disco',      # index 7
    'jazz',       # index 8
    'metal',      # index 9
    'pop'         # index 10
]

# ✅ Create labeled vectors
genre_labels_named_240 = [genre_names[i - 1] for i in genre_labels_full]
genre_labels_named_1200 = [genre_names[i - 1] for i in genre_labels_full_all]

# ✅ Quick check
print("First 12:", genre_labels_named_240[:12])
print("First 12 of full set:", genre_labels_named_1200[:12])
print("Length 240:", len(genre_labels_named_240))
print("Length 1200:", len(genre_labels_named_1200))
# Out:
# First 12: ['pop', 'pop', 'pop', 'pop', 'rock', 'rock', 'rock', 'rock', 'country', 'country', 'country', 'country']
# First 12 of full set: ['pop', 'pop', 'pop', 'pop', 'rock', 'rock', 'rock', 'rock', 'country', 'country', 'country', 'country']
# Length 240: 240
# Length 1200: 1200

# %% [markdown]
# Ok, so we aren't seeing significant clustering across time points so let's try a different approach.
#
# average voxels across a period

# %% [markdown]
# Here, we are reshaping the data so that it's containing the first 3 repetitions. The last one will be kept for testing.

# %% [markdown]
# Each repetition has 60 tracks: 10 tracks per run. We are concatentating 3 repetitions of these 60 tracks. That will total to 180 tracks total.

# %%
n_voxels = 61899
tracks = 60
timepoints_per_track = 10

sub4test_reshaped = np.transpose(sub4test[:, :3, :].reshape(n_voxels, 3, tracks, timepoints_per_track), [0,3,2,1]).reshape(n_voxels*timepoints_per_track,tracks*3)
sub4test_reshaped.shape
# Out:
# (618990, 180)

# %%
# tracks x responses @ responses x tracks = tracks x tracks
sub4test_reshaped -= sub4test_reshaped.mean(axis=0)
sub4test_reshaped /= sub4test_reshaped.std(axis=0)
tracksxtracks = sub4test_reshaped.T @ sub4test_reshaped

# %%
plt.imshow(tracksxtracks[:, :], cmap='hot')
plt.show()

# %% [markdown]
# This will be structured as track 1 rep 1, track 1 rep 2, track 1 rep 3, track 2 rep 1, etc. Each column is one track-repetition, and each row corresponds to a specific timepoint at a voxel

# %% [markdown]
# Check that it was reshaped correctly. These two should print the same thing.

# %%
# track 6, rep 0, voxel 101, timepoints 0-9
sub4test_reshaped[1000:1010, 15]
# Out:
# array([-0.24232563,  0.46284536,  0.8154308 ,  0.19840622,  0.46284536,
#         0.46284536, -0.06603287,  1.9172604 , -1.2119356 , -0.06603287],
#       dtype=float32)

# %%
print(sub4test.shape)
print(sub4test[100, 0, 50:60])
# Out:
# (61899, 4, 600)
# [-0.18326524  0.40588492  0.70046     0.18495362  0.40588492  0.40588492
#  -0.03597768  1.6210071  -0.9933467  -0.03597768]

# %%
test = np.arange(120)
test = test.reshape(2, 3, 20)
# 2 voxels, 3 repetitions, 4 * 5 track timepoints
test.shape
# Out:
# (2, 3, 20)

# %%
test_reshaped = np.transpose(test[:, :3, :].reshape(2, 3, 4, 5), [0,3,2,1]).reshape(2*5,4*3)
# voxel * timepoints_per_track, tracks * repetitions

# %%
print(test[1, 0, 0:5])
print(test_reshaped[5:10, 0])

# 2 voxels, 3 repetitions, 4 * 5 track timepoints
# 2nd voxel 2nd track 2nd rep
print(test[1, 1, 5:10])
print(test_reshaped[5:10, 4])
# Out:
# [60 61 62 63 64]
# [60 61 62 63 64]
# [85 86 87 88 89]
# [85 86 87 88 89]

# %% [markdown]
# sub1test_reshaped format:
#
# (618990, 60): voxels * 10 timepoints, 60 tracks
#
#  all timesteps for first voxel, all timesteps for second voxel, stacked. then by track
#
#  need to do that for the first three reptitions. save the last one for testing
#
#  full shape should be (voxels * )

# %%
genre_labels[0:10]
genre_180 = np.repeat(genre_labels, 3)

print(genre_180)
# Out:
# [10 10 10  3  3  3  1  1  1  4  4  4  7  7  7  9  9  9  2  2  2  5  5  5
#   6  6  6  8  8  8  9  9  9 10 10 10  5  5  5  8  8  8  3  3  3  6  6  6
#   1  1  1  2  2  2  4  4  4  7  7  7  5  5  5  1  1  1 10 10 10  3  3  3
#   8  8  8  4  4  4  2  2  2  7  7  7  9  9  9  6  6  6  7  7  7  3  3  3
#  10 10 10  9  9  9  1  1  1  5  5  5  4  4  4  2  2  2  8  8  8  6  6  6
#   8  8  8  3  3  3  2  2  2  7  7  7  4  4  4  5  5  5 10 10 10  1  1  1
#   6  6  6  9  9  9  1  1  1  8  8  8  2  2  2  4  4  4  7  7  7  6  6  6
#   5  5  5  3  3  3 10 10 10  9  9  9]

# %%
import numpy as np
from sklearn.linear_model import LogisticRegression

# Move the time dimension to be part of the features
# Result: shape (voxels * timepoints_per_track, tracks)
# X_tracks = reshaped.transpose(0, 1, 2).reshape(voxels * timepoints_per_track, tracks)

clf = LogisticRegression(random_state=0).fit(sub4test_reshaped.T, genre_180)

# %%
clf.predict(sub4test_reshaped[:, 0:1].T)
# Out:
# array([10])

# %%
genre_180[0]
# Out:
# 10

# %%
clf.score(sub4test_reshaped.T, genre_180)

import numpy as np

# Step 1: get weight vector
weights = clf.coef_[0]  # (n_features,) for binary classification

# Step 2: get top-N influential feature indices
top_feature_indices = np.argsort(np.abs(weights))[-200:]  # top 100 by absolute weight

# Step 3: convert flat index back to (voxel, timepoint)

for flat_idx in reversed(top_feature_indices):
    voxel_idx = flat_idx // timepoints_per_track
    time_idx = flat_idx % timepoints_per_track
    print(f"Voxel {voxel_idx}, Time {time_idx}: Weight {weights[flat_idx]:.4f}")
    
# Collect all voxel indices from your top features
voxel_indices = [flat_idx // timepoints_per_track for flat_idx in top_feature_indices]

# Plot histogram
plt.figure(figsize=(6, 4))
plt.hist(voxel_indices, bins=50, edgecolor='black')  # You can change bins=50 as needed
plt.xlabel("Voxel Index")
plt.ylabel("Count of Top Voxel")
plt.title("Distribution of Top-Weighted Voxels")
plt.tight_layout()
plt.show()

# let's only include each voxel once in this list so we can use it for the umap
unique_voxel_indices = np.unique(np.array(top_feature_indices) // 10)
    
# Collect all time indices from your top features
time_indices = [flat_idx % timepoints_per_track for flat_idx in top_feature_indices]

# Plot histogram
plt.figure(figsize=(6, 4))
plt.hist(time_indices, bins=np.arange(11) - 0.5, edgecolor='black', rwidth=0.9)
plt.xticks(range(10))
plt.yticks(np.arange(0, plt.gca().get_ylim()[1] + 1, 1))
plt.xlabel("Timepoint")
plt.ylabel("Count of Top Voxels")
plt.title("Distribution of Top-Weighted Timepoints")
plt.tight_layout()
plt.show()
# Out:
# Voxel 11966, Time 3: Weight 0.0019
# Voxel 273, Time 5: Weight 0.0019
# Voxel 18661, Time 3: Weight 0.0019
# Voxel 4890, Time 7: Weight -0.0019
# Voxel 20419, Time 2: Weight 0.0019
# Voxel 41018, Time 1: Weight -0.0019
# Voxel 14734, Time 1: Weight -0.0019
# Voxel 21590, Time 2: Weight 0.0018
# Voxel 9441, Time 9: Weight -0.0018
# Voxel 38684, Time 0: Weight -0.0018
# Voxel 38712, Time 0: Weight 0.0018
# Voxel 26837, Time 0: Weight -0.0018
# Voxel 17229, Time 6: Weight -0.0018
# Voxel 30412, Time 1: Weight 0.0018
# Voxel 29966, Time 8: Weight 0.0018
# Voxel 20369, Time 4: Weight 0.0018
# Voxel 49365, Time 0: Weight -0.0017
# Voxel 2559, Time 4: Weight -0.0017
# Voxel 401, Time 0: Weight -0.0017
# Voxel 31520, Time 1: Weight -0.0017
# Voxel 43619, Time 0: Weight -0.0017
# Voxel 3513, Time 9: Weight 0.0017
# Voxel 34167, Time 8: Weight -0.0017
# Voxel 10933, Time 8: Weight 0.0017
# Voxel 28379, Time 2: Weight 0.0017
# Voxel 50960, Time 9: Weight -0.0017
# Voxel 52162, Time 6: Weight -0.0017
# Voxel 48501, Time 9: Weight -0.0017
# Voxel 30393, Time 1: Weight 0.0017
# Voxel 29844, Time 9: Weight 0.0017
# Voxel 21236, Time 9: Weight 0.0017
# Voxel 14094, Time 9: Weight -0.0017
# Voxel 27343, Time 3: Weight 0.0017
# Voxel 38381, Time 0: Weight -0.0017
# Voxel 38592, Time 1: Weight -0.0017
# Voxel 50947, Time 5: Weight -0.0017
# Voxel 34913, Time 1: Weight 0.0017
# Voxel 32647, Time 5: Weight 0.0017
# Voxel 21138, Time 6: Weight -0.0017
# Voxel 47058, Time 8: Weight -0.0017
# Voxel 44372, Time 4: Weight 0.0017
# Voxel 10633, Time 8: Weight 0.0017
# Voxel 45002, Time 0: Weight -0.0017
# Voxel 45052, Time 0: Weight -0.0017
# Voxel 48183, Time 2: Weight -0.0017
# Voxel 28134, Time 6: Weight 0.0016
# Voxel 45092, Time 9: Weight -0.0016
# Voxel 46371, Time 0: Weight -0.0016
# Voxel 28702, Time 4: Weight 0.0016
# Voxel 7401, Time 4: Weight -0.0016
# Voxel 52145, Time 6: Weight -0.0016
# Voxel 19901, Time 8: Weight 0.0016
# Voxel 4179, Time 3: Weight 0.0016
# Voxel 3982, Time 6: Weight 0.0016
# Voxel 35353, Time 4: Weight 0.0016
# Voxel 47532, Time 0: Weight -0.0016
# Voxel 50339, Time 0: Weight -0.0016
# Voxel 27370, Time 7: Weight -0.0016
# Voxel 50489, Time 0: Weight -0.0016
# Voxel 4936, Time 9: Weight 0.0016
# Voxel 14112, Time 9: Weight -0.0016
# Voxel 17106, Time 2: Weight 0.0016
# Voxel 14282, Time 1: Weight 0.0016
# Voxel 32195, Time 5: Weight 0.0016
# Voxel 2328, Time 6: Weight -0.0016
# Voxel 45100, Time 0: Weight -0.0016
# Voxel 40878, Time 0: Weight -0.0016
# Voxel 15750, Time 3: Weight 0.0016
# Voxel 49677, Time 6: Weight -0.0016
# Voxel 28840, Time 7: Weight -0.0016
# Voxel 40987, Time 0: Weight -0.0016
# Voxel 35617, Time 5: Weight 0.0016
# Voxel 21121, Time 2: Weight -0.0016
# Voxel 14088, Time 1: Weight 0.0016
# Voxel 7765, Time 7: Weight -0.0016
# Voxel 45394, Time 0: Weight -0.0016
# Voxel 20511, Time 2: Weight 0.0016
# Voxel 31301, Time 9: Weight 0.0016
# Voxel 51776, Time 1: Weight -0.0016
# Voxel 51625, Time 1: Weight -0.0016
# Voxel 28119, Time 6: Weight 0.0016
# Voxel 50362, Time 0: Weight -0.0016
# Voxel 1761, Time 5: Weight -0.0016
# Voxel 57035, Time 3: Weight 0.0016
# Voxel 46863, Time 7: Weight -0.0016
# Voxel 17704, Time 4: Weight -0.0016
# Voxel 26017, Time 6: Weight -0.0016
# Voxel 24084, Time 0: Weight -0.0016
# Voxel 51480, Time 1: Weight 0.0016
# Voxel 41063, Time 0: Weight -0.0016
# Voxel 10660, Time 2: Weight 0.0016
# Voxel 34337, Time 1: Weight 0.0016
# Voxel 24327, Time 7: Weight -0.0016
# Voxel 46372, Time 0: Weight -0.0016
# Voxel 45458, Time 0: Weight -0.0016
# Voxel 16788, Time 3: Weight 0.0016
# Voxel 17852, Time 5: Weight 0.0016
# Voxel 30080, Time 5: Weight 0.0016
# Voxel 2124, Time 0: Weight 0.0016
# Voxel 47067, Time 7: Weight -0.0016
# Voxel 13969, Time 4: Weight 0.0016
# Voxel 9680, Time 7: Weight 0.0016
# Voxel 44971, Time 0: Weight -0.0016
# Voxel 46051, Time 0: Weight -0.0016
# Voxel 22645, Time 7: Weight 0.0016
# Voxel 48833, Time 0: Weight -0.0016
# Voxel 40795, Time 7: Weight 0.0016
# Voxel 39229, Time 7: Weight 0.0015
# Voxel 28851, Time 2: Weight -0.0015
# Voxel 60031, Time 1: Weight -0.0015
# Voxel 19010, Time 7: Weight -0.0015
# Voxel 23014, Time 0: Weight -0.0015
# Voxel 3480, Time 8: Weight 0.0015
# Voxel 53822, Time 7: Weight 0.0015
# Voxel 13666, Time 0: Weight -0.0015
# Voxel 32883, Time 3: Weight -0.0015
# Voxel 52970, Time 1: Weight -0.0015
# Voxel 32143, Time 0: Weight -0.0015
# Voxel 12802, Time 0: Weight -0.0015
# Voxel 45051, Time 0: Weight -0.0015
# Voxel 4930, Time 6: Weight -0.0015
# Voxel 15555, Time 8: Weight 0.0015
# Voxel 51018, Time 3: Weight -0.0015
# Voxel 49887, Time 0: Weight -0.0015
# Voxel 43612, Time 0: Weight -0.0015
# Voxel 21106, Time 7: Weight -0.0015
# Voxel 47297, Time 0: Weight -0.0015
# Voxel 4696, Time 7: Weight 0.0015
# Voxel 2423, Time 9: Weight -0.0015
# Voxel 5664, Time 4: Weight -0.0015
# Voxel 31622, Time 7: Weight -0.0015
# Voxel 46786, Time 6: Weight -0.0015
# Voxel 56576, Time 8: Weight 0.0015
# Voxel 49802, Time 7: Weight -0.0015
# Voxel 22985, Time 0: Weight -0.0015
# Voxel 46491, Time 0: Weight -0.0015
# Voxel 31583, Time 6: Weight 0.0015
# Voxel 38614, Time 1: Weight -0.0015
# Voxel 51013, Time 0: Weight -0.0015
# Voxel 28804, Time 4: Weight 0.0015
# Voxel 13643, Time 4: Weight 0.0015
# Voxel 3440, Time 7: Weight 0.0015
# Voxel 30318, Time 5: Weight 0.0015
# Voxel 41913, Time 5: Weight 0.0015
# Voxel 60944, Time 6: Weight -0.0015
# Voxel 46434, Time 0: Weight -0.0015
# Voxel 1980, Time 7: Weight -0.0015
# Voxel 30161, Time 2: Weight 0.0015
# Voxel 36259, Time 0: Weight -0.0015
# Voxel 23909, Time 7: Weight -0.0015
# Voxel 42316, Time 0: Weight -0.0015
# Voxel 49754, Time 8: Weight -0.0015
# Voxel 18518, Time 5: Weight 0.0015
# Voxel 3161, Time 8: Weight -0.0015
# Voxel 36634, Time 2: Weight 0.0015
# Voxel 12598, Time 9: Weight 0.0015
# Voxel 56558, Time 8: Weight 0.0015
# Voxel 44650, Time 0: Weight -0.0015
# Voxel 2330, Time 5: Weight 0.0015
# Voxel 30222, Time 4: Weight 0.0015
# Voxel 29707, Time 6: Weight -0.0015
# Voxel 51198, Time 6: Weight -0.0015
# Voxel 21568, Time 6: Weight 0.0015
# Voxel 51718, Time 6: Weight 0.0015
# Voxel 3291, Time 1: Weight -0.0015
# Voxel 19371, Time 3: Weight 0.0015
# Voxel 3221, Time 7: Weight -0.0015
# Voxel 18548, Time 3: Weight 0.0015
# Voxel 27268, Time 1: Weight 0.0015
# Voxel 6860, Time 5: Weight -0.0015
# Voxel 26840, Time 6: Weight -0.0015
# Voxel 53663, Time 4: Weight 0.0015
# Voxel 46995, Time 3: Weight -0.0015
# Voxel 59269, Time 4: Weight 0.0015
# Voxel 19901, Time 9: Weight 0.0015
# Voxel 27688, Time 0: Weight -0.0015
# Voxel 42260, Time 0: Weight -0.0015
# Voxel 21634, Time 1: Weight 0.0015
# Voxel 51845, Time 0: Weight -0.0015
# Voxel 37735, Time 9: Weight 0.0015
# Voxel 1644, Time 4: Weight 0.0015
# Voxel 51777, Time 0: Weight -0.0015
# Voxel 35254, Time 7: Weight -0.0015
# Voxel 51751, Time 0: Weight -0.0015
# Voxel 24359, Time 1: Weight 0.0015
# Voxel 9450, Time 1: Weight -0.0015
# Voxel 47052, Time 6: Weight -0.0015
# Voxel 1736, Time 8: Weight 0.0015
# Voxel 23255, Time 8: Weight 0.0015
# Voxel 30142, Time 4: Weight 0.0015
# Voxel 42549, Time 3: Weight 0.0015
# Voxel 13921, Time 0: Weight 0.0015
# Voxel 42234, Time 0: Weight -0.0015
# Voxel 37555, Time 7: Weight 0.0015
# Voxel 13947, Time 4: Weight 0.0015
# Voxel 20384, Time 5: Weight 0.0015
# Voxel 25593, Time 7: Weight -0.0015
# Voxel 46433, Time 0: Weight -0.0015
# Voxel 25975, Time 7: Weight -0.0015
# Voxel 35634, Time 6: Weight 0.0015

# %% [markdown]
# inspect the weights to see what it's sensitive to. some weights may be high (timesteps * voxels)
#
# maybe theres a time step or voxel where the weight is particularly high

# %% [markdown]
# make a new genre vector to fit the t1r1, t1r2, t1r3, t2t1, etc. Don't need to include time points, because that is already encoded in the reshaped matrix

# %%
# Repeat each genre 3 times (for 3 reps)
y = np.repeat(genre_labels, 3)  # length = 180
le = LabelEncoder()
y_encoded = le.fit_transform(y)

# Check shape
print("Genre vector shape:", y.shape)
assert y.shape[0] == sub4test_reshaped.T.shape[0], "Mismatch with number of columns in X"

print("Genre labels (first 10):", genre_labels[:10])  # should be per-track
print("y (first 30):", y[:30])  # should repeat each genre 3 times
# Out:
# Genre vector shape: (180,)
# Genre labels (first 10): [10, 3, 1, 4, 7, 9, 2, 5, 6, 8]
# y (first 30): [10 10 10  3  3  3  1  1  1  4  4  4  7  7  7  9  9  9  2  2  2  5  5  5
#   6  6  6  8  8  8]

# %% [markdown]
# UMAP on learned weight voxels

# %%
# Subset the original voxel data using top-weighted voxels ---
samples = 180

# Your input matrix
# sub1test_reshaped: shape (618990, 180)

# Compute row indices for timepoints 6–9 of each selected voxel
timepoints_to_avg = np.array([6, 7, 8, 9])
row_indices = unique_voxel_indices[:, None] * timepoints_per_track + timepoints_to_avg  # shape: (n_voxels_kept, 4)

# Extract and average those rows across the timepoint axis
voxel_avg_values = sub4test_reshaped[row_indices, :].mean(axis=1)  # shape: (n_voxels_kept, 180)

# Transpose to shape (samples, voxels)
X_avg = voxel_avg_values.T  # shape: (180, n_voxels_kept)

# --- Step 6: UMAP on PCA output ---
reducer = umap.UMAP(n_neighbors=15, min_dist=0.1, n_components=2, random_state=42)
embedding = reducer.fit_transform(X_avg)

# Step 5: Visualize ---
plt.figure(figsize=(10, 6))
scatter = plt.scatter(embedding[:, 0], embedding[:, 1], c=y_encoded, cmap='Spectral', s=15)
plt.colorbar(scatter, label='Genre Label')
plt.title("UMAP projection of top-weighted voxels")
plt.xlabel("UMAP-1")
plt.ylabel("UMAP-2")
plt.tight_layout()
plt.show()
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(

# %% [markdown]
# Heat map again using only the voxels of interest.

# %%
# Step 1: Select only the top voxel-time features
X_top = sub4test_reshaped[top_feature_indices, :]  # shape: (100, 180)

# Step 2: Transpose to shape (180 samples × 100 features)
X_top = X_top.T  # shape: (180, 100)

# Step 3: Z-score across features (columns)
X_top_zscored = (X_top - X_top.mean(axis=0)) / X_top.std(axis=0)

# Step 4: Compute similarity (dot product across samples)
similarity_matrix = X_top_zscored @ X_top_zscored.T  # shape: (180, 180)

# Step 5: Plot heatmap
import matplotlib.pyplot as plt

plt.figure(figsize=(6, 5))
plt.imshow(similarity_matrix, cmap='hot')
plt.title("Track × Track Similarity (Top 100 Voxel-Time Features)")
plt.colorbar()
plt.tight_layout()
plt.show()
