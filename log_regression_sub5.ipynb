# %%
from sklearn.datasets import fetch_openml
from sklearn.decomposition import PCA
import numpy as np
import matplotlib.pyplot as plt
import scipy.io as sio
# %matplotlib inline


# Dimension reduction and clustering libraries
# %pip install umap-learn
import umap
# %pip install hdbscan
import hdbscan
import sklearn.cluster as cluster
from sklearn.metrics import adjusted_rand_score, adjusted_mutual_info_score
from sklearn.preprocessing import LabelEncoder
# Out:
# Requirement already satisfied: umap-learn in /opt/anaconda3/lib/python3.12/site-packages (0.5.7)
# Requirement already satisfied: numpy>=1.17 in /opt/anaconda3/lib/python3.12/site-packages (from umap-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from umap-learn) (1.13.1)
# Requirement already satisfied: scikit-learn>=0.22 in /opt/anaconda3/lib/python3.12/site-packages (from umap-learn) (1.5.1)
# Requirement already satisfied: numba>=0.51.2 in /opt/anaconda3/lib/python3.12/site-packages (from umap-learn) (0.60.0)
# Requirement already satisfied: pynndescent>=0.5 in /opt/anaconda3/lib/python3.12/site-packages (from umap-learn) (0.5.13)
# Requirement already satisfied: tqdm in /opt/anaconda3/lib/python3.12/site-packages (from umap-learn) (4.66.5)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /opt/anaconda3/lib/python3.12/site-packages (from numba>=0.51.2->umap-learn) (0.43.0)
# Requirement already satisfied: joblib>=0.11 in /opt/anaconda3/lib/python3.12/site-packages (from pynndescent>=0.5->umap-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from scikit-learn>=0.22->umap-learn) (3.5.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: hdbscan in /opt/anaconda3/lib/python3.12/site-packages (0.8.40)
# Requirement already satisfied: numpy<3,>=1.20 in /opt/anaconda3/lib/python3.12/site-packages (from hdbscan) (1.26.4)
# Requirement already satisfied: scipy>=1.0 in /opt/anaconda3/lib/python3.12/site-packages (from hdbscan) (1.13.1)
# Requirement already satisfied: scikit-learn>=0.20 in /opt/anaconda3/lib/python3.12/site-packages (from hdbscan) (1.5.1)
# Requirement already satisfied: joblib>=1.0 in /opt/anaconda3/lib/python3.12/site-packages (from hdbscan) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from scikit-learn>=0.20->hdbscan) (3.5.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Load in the test data.

# %%
sub5test = np.load("/Users/jenniferarakaki/Documents/neuro120/8275363/sub-005_Resp_Test.npy")
print(sub5test.shape)
# Out:
# (53421, 4, 600)

# %% [markdown]
# Create a genre label vector to feed into the UMAP function.

# %%
# Load the .mat file (adjust the path if needed)
data = sio.loadmat('/Users/jenniferarakaki/Documents/neuro120/8275363/AcrossGenre_Order_Test.mat')
test_run_data = data['across_genre_rn_test']  # shape: (6 runs, 4 reps, 10 genres)

# Step 1: Extract numeric genre IDs
genre_labels = []
for run in range(6):  # 6 runs
    for track_pos in range(10):  # 10 tracks per run
        genre_id = int(test_run_data[run, 0, track_pos])
        genre_labels.append(genre_id)  # values: 1–10

# Step 2: Repeat each genre label 4 times (for 4 reps)
genre_labels_full = np.repeat(genre_labels, 4)  # shape: (240,)

# Step 3: Repeat for 5 subjects
genre_labels_full_all = np.tile(genre_labels_full, 5)  # shape: (1200,)

# Step 4: Convert to names using the corrected mapping
genre_names = [
    'country',    # index 1
    'reggae',     # index 2
    'rock',       # index 3
    'blues',      # index 4
    'classical',  # index 5
    'hiphop',     # index 6
    'disco',      # index 7
    'jazz',       # index 8
    'metal',      # index 9
    'pop'         # index 10
]

# ✅ Create labeled vectors
genre_labels_named_240 = [genre_names[i - 1] for i in genre_labels_full]
genre_labels_named_1200 = [genre_names[i - 1] for i in genre_labels_full_all]

# ✅ Quick check
print("First 12:", genre_labels_named_240[:12])
print("First 12 of full set:", genre_labels_named_1200[:12])
print("Length 240:", len(genre_labels_named_240))
print("Length 1200:", len(genre_labels_named_1200))
# Out:
# First 12: ['pop', 'pop', 'pop', 'pop', 'rock', 'rock', 'rock', 'rock', 'country', 'country', 'country', 'country']
# First 12 of full set: ['pop', 'pop', 'pop', 'pop', 'rock', 'rock', 'rock', 'rock', 'country', 'country', 'country', 'country']
# Length 240: 240
# Length 1200: 1200

# %% [markdown]
# Ok, so we aren't seeing significant clustering across time points so let's try a different approach.
#
# average voxels across a period

# %% [markdown]
# Here, we are reshaping the data so that it's containing the first 3 repetitions. The last one will be kept for testing.

# %% [markdown]
# Each repetition has 60 tracks: 10 tracks per run. We are concatentating 3 repetitions of these 60 tracks. That will total to 180 tracks total.

# %%
n_voxels = 53421
tracks = 60
timepoints_per_track = 10

sub5test_reshaped = np.transpose(sub5test[:, :3, :].reshape(n_voxels, 3, tracks, timepoints_per_track), [0,3,2,1]).reshape(n_voxels*timepoints_per_track,tracks*3)
sub5test_reshaped.shape
# Out:
# (534210, 180)

# %%
# tracks x responses @ responses x tracks = tracks x tracks
sub5test_reshaped -= sub5test_reshaped.mean(axis=0)
sub5test_reshaped /= sub5test_reshaped.std(axis=0)
tracksxtracks = sub5test_reshaped.T @ sub5test_reshaped

# %%
plt.imshow(tracksxtracks[:, :], cmap='hot')
plt.show()

# %% [markdown]
# This will be structured as track 1 rep 1, track 1 rep 2, track 1 rep 3, track 2 rep 1, etc. Each column is one track-repetition, and each row corresponds to a specific timepoint at a voxel

# %% [markdown]
# Check that it was reshaped correctly. These two should print the same thing.

# %%
# track 6, rep 0, voxel 101, timepoints 0-9
sub5test_reshaped[1000:1010, 15]
# Out:
# array([-0.09212317,  0.7416391 ,  1.5754014 , -1.7596478 ,  0.46371835,
#         0.46371835, -0.09212317, -1.4817268 , -0.6479647 , -1.2038063 ],
#       dtype=float32)

# %%
print(sub5test.shape)
print(sub5test[100, 0, 50:60])
# Out:
# (53421, 4, 600)
# [ 0.02384315  0.8872899   1.7507367  -1.7030504   0.5994743   0.5994743
#   0.02384315 -1.4152347  -0.55178803 -1.1274192 ]

# %%
test = np.arange(120)
test = test.reshape(2, 3, 20)
# 2 voxels, 3 repetitions, 4 * 5 track timepoints
test.shape
# Out:
# (2, 3, 20)

# %%
test_reshaped = np.transpose(test[:, :3, :].reshape(2, 3, 4, 5), [0,3,2,1]).reshape(2*5,4*3)
# voxel * timepoints_per_track, tracks * repetitions

# %%
print(test[1, 0, 0:5])
print(test_reshaped[5:10, 0])

# 2 voxels, 3 repetitions, 4 * 5 track timepoints
# 2nd voxel 2nd track 2nd rep
print(test[1, 1, 5:10])
print(test_reshaped[5:10, 4])
# Out:
# [60 61 62 63 64]
# [60 61 62 63 64]
# [85 86 87 88 89]
# [85 86 87 88 89]

# %% [markdown]
# sub1test_reshaped format:
#
# (534210, 60): voxels * 10 timepoints, 60 tracks
#
#  all timesteps for first voxel, all timesteps for second voxel, stacked. then by track
#
#  need to do that for the first three reptitions. save the last one for testing
#
#  full shape should be (voxels * )

# %%
genre_labels[0:10]
genre_180 = np.repeat(genre_labels, 3)

print(genre_180)
# Out:
# [10 10 10  3  3  3  1  1  1  4  4  4  7  7  7  9  9  9  2  2  2  5  5  5
#   6  6  6  8  8  8  9  9  9 10 10 10  5  5  5  8  8  8  3  3  3  6  6  6
#   1  1  1  2  2  2  4  4  4  7  7  7  5  5  5  1  1  1 10 10 10  3  3  3
#   8  8  8  4  4  4  2  2  2  7  7  7  9  9  9  6  6  6  7  7  7  3  3  3
#  10 10 10  9  9  9  1  1  1  5  5  5  4  4  4  2  2  2  8  8  8  6  6  6
#   8  8  8  3  3  3  2  2  2  7  7  7  4  4  4  5  5  5 10 10 10  1  1  1
#   6  6  6  9  9  9  1  1  1  8  8  8  2  2  2  4  4  4  7  7  7  6  6  6
#   5  5  5  3  3  3 10 10 10  9  9  9]

# %%
import numpy as np
from sklearn.linear_model import LogisticRegression

# Move the time dimension to be part of the features
# Result: shape (voxels * timepoints_per_track, tracks)
# X_tracks = reshaped.transpose(0, 1, 2).reshape(voxels * timepoints_per_track, tracks)

clf = LogisticRegression(random_state=0).fit(sub5test_reshaped.T, genre_180)

# %%
clf.predict(sub5test_reshaped[:, 0:1].T)
# Out:
# array([10])

# %%
genre_180[0]
# Out:
# 10

# %%
clf.score(sub5test_reshaped.T, genre_180)

import numpy as np

# Step 1: get weight vector
weights = clf.coef_[0]  # (n_features,) for binary classification

# Step 2: get top-N influential feature indices
top_feature_indices = np.argsort(np.abs(weights))[-200:]  # top 100 by absolute weight

# Step 3: convert flat index back to (voxel, timepoint)

for flat_idx in reversed(top_feature_indices):
    voxel_idx = flat_idx // timepoints_per_track
    time_idx = flat_idx % timepoints_per_track
    print(f"Voxel {voxel_idx}, Time {time_idx}: Weight {weights[flat_idx]:.4f}")
    
# Collect all voxel indices from your top features
voxel_indices = [flat_idx // timepoints_per_track for flat_idx in top_feature_indices]

# Plot histogram
plt.figure(figsize=(6, 4))
plt.hist(voxel_indices, bins=50, edgecolor='black')  # You can change bins=50 as needed
plt.xlabel("Voxel Index")
plt.ylabel("Count of Top Voxel")
plt.title("Distribution of Top-Weighted Voxels")
plt.tight_layout()
plt.show()

# let's only include each voxel once in this list so we can use it for the umap
unique_voxel_indices = np.unique(np.array(top_feature_indices) // 10)
    
# Collect all time indices from your top features
time_indices = [flat_idx % timepoints_per_track for flat_idx in top_feature_indices]

# Plot histogram
plt.figure(figsize=(6, 4))
plt.hist(time_indices, bins=np.arange(11) - 0.5, edgecolor='black', rwidth=0.9)
plt.xticks(range(10))
plt.yticks(np.arange(0, plt.gca().get_ylim()[1] + 1, 1))
plt.xlabel("Timepoint")
plt.ylabel("Count of Top Voxels")
plt.title("Distribution of Top-Weighted Timepoints")
plt.tight_layout()
plt.show()
# Out:
# Voxel 17410, Time 5: Weight 0.0029
# Voxel 15769, Time 9: Weight -0.0028
# Voxel 40771, Time 6: Weight 0.0027
# Voxel 15749, Time 9: Weight -0.0026
# Voxel 4007, Time 4: Weight -0.0026
# Voxel 16816, Time 5: Weight 0.0025
# Voxel 19502, Time 4: Weight 0.0025
# Voxel 14362, Time 3: Weight -0.0025
# Voxel 5591, Time 1: Weight -0.0025
# Voxel 9190, Time 6: Weight 0.0025
# Voxel 12956, Time 9: Weight -0.0024
# Voxel 40399, Time 7: Weight 0.0024
# Voxel 2749, Time 8: Weight -0.0024
# Voxel 52600, Time 1: Weight 0.0024
# Voxel 25104, Time 2: Weight 0.0024
# Voxel 22030, Time 6: Weight 0.0024
# Voxel 18135, Time 5: Weight 0.0024
# Voxel 46373, Time 7: Weight 0.0024
# Voxel 32743, Time 0: Weight 0.0024
# Voxel 32270, Time 1: Weight -0.0024
# Voxel 16778, Time 8: Weight 0.0024
# Voxel 37884, Time 7: Weight 0.0024
# Voxel 30906, Time 1: Weight -0.0024
# Voxel 21771, Time 2: Weight -0.0024
# Voxel 19304, Time 0: Weight 0.0024
# Voxel 35124, Time 1: Weight 0.0024
# Voxel 48168, Time 0: Weight -0.0023
# Voxel 2272, Time 7: Weight -0.0023
# Voxel 46936, Time 1: Weight 0.0023
# Voxel 6349, Time 0: Weight -0.0023
# Voxel 4451, Time 5: Weight 0.0023
# Voxel 42320, Time 8: Weight -0.0023
# Voxel 41584, Time 3: Weight 0.0023
# Voxel 9739, Time 1: Weight -0.0023
# Voxel 18501, Time 4: Weight 0.0023
# Voxel 1904, Time 6: Weight -0.0023
# Voxel 10773, Time 1: Weight -0.0023
# Voxel 18291, Time 9: Weight -0.0023
# Voxel 10367, Time 4: Weight -0.0023
# Voxel 16957, Time 1: Weight 0.0023
# Voxel 436, Time 7: Weight 0.0023
# Voxel 22203, Time 5: Weight 0.0023
# Voxel 1055, Time 8: Weight -0.0023
# Voxel 3147, Time 2: Weight 0.0023
# Voxel 2516, Time 7: Weight -0.0023
# Voxel 5638, Time 2: Weight 0.0023
# Voxel 50145, Time 9: Weight -0.0023
# Voxel 6157, Time 2: Weight 0.0023
# Voxel 23983, Time 2: Weight 0.0023
# Voxel 8873, Time 4: Weight -0.0023
# Voxel 44284, Time 0: Weight 0.0023
# Voxel 1629, Time 2: Weight 0.0023
# Voxel 7892, Time 6: Weight 0.0023
# Voxel 38693, Time 0: Weight 0.0023
# Voxel 10597, Time 8: Weight 0.0022
# Voxel 19484, Time 4: Weight 0.0022
# Voxel 1227, Time 2: Weight -0.0022
# Voxel 50146, Time 2: Weight 0.0022
# Voxel 22303, Time 9: Weight 0.0022
# Voxel 159, Time 8: Weight 0.0022
# Voxel 22275, Time 8: Weight -0.0022
# Voxel 30907, Time 1: Weight -0.0022
# Voxel 13182, Time 0: Weight -0.0022
# Voxel 740, Time 2: Weight -0.0022
# Voxel 4023, Time 9: Weight -0.0022
# Voxel 9851, Time 9: Weight -0.0022
# Voxel 11047, Time 2: Weight 0.0022
# Voxel 3626, Time 6: Weight 0.0022
# Voxel 15311, Time 9: Weight -0.0022
# Voxel 11314, Time 3: Weight -0.0022
# Voxel 1963, Time 0: Weight -0.0022
# Voxel 18087, Time 4: Weight -0.0022
# Voxel 4971, Time 7: Weight 0.0022
# Voxel 33739, Time 3: Weight -0.0022
# Voxel 30353, Time 0: Weight -0.0022
# Voxel 4320, Time 5: Weight 0.0022
# Voxel 36911, Time 7: Weight -0.0022
# Voxel 4616, Time 8: Weight -0.0022
# Voxel 39241, Time 2: Weight -0.0022
# Voxel 20070, Time 0: Weight -0.0022
# Voxel 35002, Time 3: Weight -0.0022
# Voxel 16974, Time 1: Weight 0.0022
# Voxel 37557, Time 6: Weight -0.0022
# Voxel 49908, Time 0: Weight -0.0022
# Voxel 36640, Time 5: Weight -0.0022
# Voxel 10563, Time 1: Weight -0.0022
# Voxel 11556, Time 7: Weight 0.0022
# Voxel 34505, Time 1: Weight 0.0022
# Voxel 377, Time 2: Weight -0.0022
# Voxel 35418, Time 1: Weight 0.0022
# Voxel 19290, Time 0: Weight 0.0022
# Voxel 37985, Time 0: Weight -0.0022
# Voxel 18582, Time 1: Weight 0.0022
# Voxel 16993, Time 2: Weight -0.0022
# Voxel 1966, Time 0: Weight -0.0022
# Voxel 45744, Time 3: Weight 0.0022
# Voxel 16802, Time 5: Weight 0.0022
# Voxel 4920, Time 7: Weight -0.0022
# Voxel 147, Time 1: Weight -0.0022
# Voxel 6682, Time 7: Weight 0.0022
# Voxel 40262, Time 4: Weight 0.0022
# Voxel 28116, Time 7: Weight 0.0022
# Voxel 6213, Time 0: Weight 0.0022
# Voxel 39505, Time 1: Weight 0.0022
# Voxel 4312, Time 7: Weight 0.0022
# Voxel 25013, Time 8: Weight 0.0022
# Voxel 11441, Time 1: Weight -0.0022
# Voxel 34090, Time 1: Weight 0.0022
# Voxel 28307, Time 9: Weight -0.0022
# Voxel 12641, Time 4: Weight 0.0022
# Voxel 23875, Time 9: Weight 0.0021
# Voxel 17816, Time 0: Weight -0.0021
# Voxel 50547, Time 3: Weight 0.0021
# Voxel 7890, Time 7: Weight 0.0021
# Voxel 7296, Time 2: Weight 0.0021
# Voxel 44542, Time 5: Weight 0.0021
# Voxel 9507, Time 7: Weight -0.0021
# Voxel 20799, Time 5: Weight 0.0021
# Voxel 8080, Time 0: Weight -0.0021
# Voxel 37285, Time 1: Weight -0.0021
# Voxel 19258, Time 4: Weight -0.0021
# Voxel 50127, Time 4: Weight -0.0021
# Voxel 6870, Time 7: Weight 0.0021
# Voxel 10281, Time 7: Weight 0.0021
# Voxel 4322, Time 2: Weight 0.0021
# Voxel 13103, Time 5: Weight -0.0021
# Voxel 2866, Time 3: Weight 0.0021
# Voxel 51212, Time 3: Weight 0.0021
# Voxel 7779, Time 1: Weight -0.0021
# Voxel 4205, Time 2: Weight -0.0021
# Voxel 9889, Time 9: Weight -0.0021
# Voxel 38893, Time 9: Weight -0.0021
# Voxel 36054, Time 1: Weight -0.0021
# Voxel 39962, Time 1: Weight 0.0021
# Voxel 15808, Time 0: Weight -0.0021
# Voxel 1448, Time 5: Weight -0.0021
# Voxel 14794, Time 6: Weight 0.0021
# Voxel 21752, Time 4: Weight -0.0021
# Voxel 40774, Time 4: Weight 0.0021
# Voxel 367, Time 3: Weight 0.0021
# Voxel 17275, Time 0: Weight 0.0021
# Voxel 21969, Time 9: Weight -0.0021
# Voxel 18050, Time 6: Weight 0.0021
# Voxel 15604, Time 6: Weight 0.0021
# Voxel 37811, Time 6: Weight 0.0021
# Voxel 32976, Time 2: Weight -0.0021
# Voxel 28096, Time 7: Weight 0.0021
# Voxel 48736, Time 2: Weight 0.0021
# Voxel 714, Time 1: Weight 0.0021
# Voxel 42091, Time 6: Weight 0.0021
# Voxel 13246, Time 7: Weight 0.0021
# Voxel 33467, Time 0: Weight -0.0021
# Voxel 25139, Time 1: Weight 0.0021
# Voxel 10793, Time 3: Weight -0.0021
# Voxel 3943, Time 8: Weight -0.0021
# Voxel 32883, Time 8: Weight 0.0021
# Voxel 20334, Time 2: Weight -0.0021
# Voxel 33719, Time 4: Weight -0.0021
# Voxel 6139, Time 2: Weight 0.0021
# Voxel 9557, Time 1: Weight 0.0021
# Voxel 38064, Time 0: Weight 0.0021
# Voxel 49533, Time 7: Weight -0.0021
# Voxel 49127, Time 6: Weight -0.0021
# Voxel 8178, Time 9: Weight 0.0021
# Voxel 17177, Time 8: Weight 0.0021
# Voxel 9577, Time 7: Weight 0.0021
# Voxel 35004, Time 6: Weight -0.0021
# Voxel 32250, Time 0: Weight -0.0021
# Voxel 28290, Time 9: Weight -0.0021
# Voxel 16, Time 3: Weight 0.0021
# Voxel 7623, Time 1: Weight -0.0021
# Voxel 2443, Time 4: Weight -0.0021
# Voxel 26561, Time 5: Weight -0.0021
# Voxel 25353, Time 1: Weight 0.0021
# Voxel 12676, Time 0: Weight -0.0021
# Voxel 5839, Time 3: Weight -0.0021
# Voxel 8806, Time 0: Weight -0.0021
# Voxel 2570, Time 7: Weight -0.0021
# Voxel 21643, Time 4: Weight -0.0021
# Voxel 9629, Time 0: Weight 0.0021
# Voxel 44225, Time 2: Weight -0.0021
# Voxel 16397, Time 1: Weight -0.0021
# Voxel 7456, Time 4: Weight -0.0021
# Voxel 49303, Time 6: Weight 0.0021
# Voxel 29100, Time 8: Weight 0.0021
# Voxel 40067, Time 0: Weight -0.0021
# Voxel 49904, Time 1: Weight -0.0021
# Voxel 34521, Time 0: Weight -0.0021
# Voxel 20646, Time 2: Weight 0.0021
# Voxel 23802, Time 8: Weight -0.0021
# Voxel 4319, Time 5: Weight 0.0021
# Voxel 33626, Time 2: Weight -0.0021
# Voxel 2794, Time 2: Weight 0.0021
# Voxel 10220, Time 2: Weight -0.0021
# Voxel 41373, Time 3: Weight 0.0021
# Voxel 6229, Time 2: Weight 0.0021
# Voxel 6317, Time 0: Weight 0.0021
# Voxel 13010, Time 5: Weight 0.0021
# Voxel 1710, Time 9: Weight -0.0021
# Voxel 12957, Time 9: Weight -0.0021

# %% [markdown]
# inspect the weights to see what it's sensitive to. some weights may be high (timesteps * voxels)
#
# maybe theres a time step or voxel where the weight is particularly high

# %% [markdown]
# make a new genre vector to fit the t1r1, t1r2, t1r3, t2t1, etc. Don't need to include time points, because that is already encoded in the reshaped matrix

# %%
# Repeat each genre 3 times (for 3 reps)
y = np.repeat(genre_labels, 3)  # length = 180
le = LabelEncoder()
y_encoded = le.fit_transform(y)

# Check shape
print("Genre vector shape:", y.shape)
assert y.shape[0] == sub5test_reshaped.T.shape[0], "Mismatch with number of columns in X"

print("Genre labels (first 10):", genre_labels[:10])  # should be per-track
print("y (first 30):", y[:30])  # should repeat each genre 3 times
# Out:
# Genre vector shape: (180,)
# Genre labels (first 10): [10, 3, 1, 4, 7, 9, 2, 5, 6, 8]
# y (first 30): [10 10 10  3  3  3  1  1  1  4  4  4  7  7  7  9  9  9  2  2  2  5  5  5
#   6  6  6  8  8  8]

# %% [markdown]
# UMAP on learned weight voxels

# %%
# Subset the original voxel data using top-weighted voxels ---
samples = 180

# Your input matrix
# sub1test_reshaped: shape (534210, 180)

# Compute row indices for timepoints 6–9 of each selected voxel
timepoints_to_avg = np.array([6, 7, 8, 9])
row_indices = unique_voxel_indices[:, None] * timepoints_per_track + timepoints_to_avg  # shape: (n_voxels_kept, 4)

# Extract and average those rows across the timepoint axis
voxel_avg_values = sub5test_reshaped[row_indices, :].mean(axis=1)  # shape: (n_voxels_kept, 180)

# Transpose to shape (samples, voxels)
X_avg = voxel_avg_values.T  # shape: (180, n_voxels_kept)

# --- Step 6: UMAP on PCA output ---
reducer = umap.UMAP(n_neighbors=15, min_dist=0.1, n_components=2, random_state=42)
embedding = reducer.fit_transform(X_avg)

# Step 5: Visualize ---
plt.figure(figsize=(10, 6))
scatter = plt.scatter(embedding[:, 0], embedding[:, 1], c=y_encoded, cmap='Spectral', s=15)
plt.colorbar(scatter, label='Genre Label')
plt.title("UMAP projection of top-weighted voxels")
plt.xlabel("UMAP-1")
plt.ylabel("UMAP-2")
plt.tight_layout()
plt.show()
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(

# %%
# Step 1: Select only the top voxel-time features
X_top = sub5test_reshaped[top_feature_indices, :]  # shape: (100, 180)

# Step 2: Transpose to shape (180 samples × 100 features)
X_top = X_top.T  # shape: (180, 100)

# Step 3: Z-score across features (columns)
X_top_zscored = (X_top - X_top.mean(axis=0)) / X_top.std(axis=0)

# Step 4: Compute similarity (dot product across samples)
similarity_matrix = X_top_zscored @ X_top_zscored.T  # shape: (180, 180)

# Step 5: Plot heatmap
import matplotlib.pyplot as plt

plt.figure(figsize=(6, 5))
plt.imshow(similarity_matrix, cmap='hot')
plt.title("Track × Track Similarity (Top 100 Voxel-Time Features)")
plt.colorbar()
plt.tight_layout()
plt.show()
